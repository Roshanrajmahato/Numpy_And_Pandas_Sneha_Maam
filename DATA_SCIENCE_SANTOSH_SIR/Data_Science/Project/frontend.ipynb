# %%
import joblib
import pandas as pd
from dotenv import load_dotenv
import os

# %%
model = joblib.load('model.pkl')

# %%
model.predict([[1]]) # the  we train the model in 2D so we have to pass it in 2D only
# Out:
# C:\Users\Roshan raj Mahato\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34745.39833481])

# %%
new_input = pd.DataFrame({'YearsExperience':[1,2,3,4,5]}) # Other way to pass the input in predict
output = model.predict(new_input)

# %%
new_input.values
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]], dtype=int64)

# %%
HF_TOKEN = os.environ.get("hugg_token")

HF_TOKEN

# %%
import os
import requests

API_URL = "https://router.huggingface.co/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {HF_TOKEN}",
}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

response = query({
    "messages": [
        {
            "role": "user",
            "content": f'''
            conclusion for the given input and output
            Scenario:I have used ML model for Salary prediction
            Input : {new_input.values}
            Output : {output}
            
            Expected result : write the conclusion for salary prediction based on input
            and you have to conclude for all the Input values and why this much salary ?
            '''
        }
    ],
    "model": "deepseek-ai/DeepSeek-R1:novita"
})
print(response)
# result = response['choices'][0]['message']['content']
# Out:
# {'error': 'Invalid username or password.'}

# %%
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 print(result)
#
# NameError: name 'result' is not defined
