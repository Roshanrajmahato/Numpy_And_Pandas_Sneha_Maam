# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from category_encoders import TargetEncoder

# %%
df=pd.read_csv(r"D:\Roshan raj Mahato\Desktop\Data Analytics\Data_Science_By_Santash_Sir\Datasets\student_performance.csv")

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
X=df.drop('Performance Index',axis=1)
y=df['Performance Index']

# %%
num_cols=X.select_dtypes(include='number').columns
obj_cols=X.select_dtypes(include='object').columns

# %%
obj_cols
# Out:
# Index(['Extracurricular Activities'], dtype='object')

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,train_size=0.8,random_state=42)

# %% [markdown]
# # Label Encoder

# %%
encoder=LabelEncoder()

# %%
encoder.fit_transform(df['Extracurricular Activities'])
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
Xtrain['Extracurricular Activities']=encoder.fit_transform(Xtrain['Extracurricular Activities'])

# %% [markdown]
# # OneHotEncoder

# %%
OHEncoder=OneHotEncoder(sparse_output=False)

# %%
values=OHEncoder.fit_transform(Xtrain[obj_cols])
column_names=OHEncoder.get_feature_names_out()

# %%
Xtrain[column_names]=OHEncoder.fit_transform(Xtrain[['Extracurricular Activities']])

# %%
values=OHEncoder.fit_transform(df[['Extracurricular Activities']])
