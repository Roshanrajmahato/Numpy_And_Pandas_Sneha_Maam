# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler

# %%
df=pd.read_csv(r"D:\Roshan raj Mahato\Desktop\Data Analytics\Data_Science_By_Santash_Sir\Datasets\Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ### Standard Scalar

# %%
scaling_SS=StandardScaler()
res=scaling_SS.fit_transform(df)
# fit :- get the mean and standard deviation of each features , then it scale the features with it with z score formula

# %%
res
# Out:
# array([[-1.51005294, -1.36011263],
#        [-1.43837321, -1.10552744],
#        [-1.36669348, -1.419919  ],
#        [-1.18749416, -1.20495739],
#        [-1.11581443, -1.33978143],
#        [-0.86493538, -0.71830716],
#        [-0.82909552, -0.58815781],
#        [-0.75741579, -0.79981746],
#        [-0.75741579, -0.42881019],
#        [-0.57821647, -0.69801306],
#        [-0.50653674, -0.47433279],
#        [-0.47069688, -0.74976858],
#        [-0.47069688, -0.70662043],
#        [-0.43485702, -0.70201994],
#        [-0.29149756, -0.55250402],
#        [-0.1481381 , -0.29921736],
#        [-0.07645838, -0.37004264],
#        [-0.00477865,  0.26285865],
#        [ 0.21026054,  0.19885989],
#        [ 0.2461004 ,  0.66547573],
#        [ 0.53281931,  0.58377993],
#        [ 0.6403389 ,  0.82623317],
#        [ 0.92705781,  0.93861127],
#        [ 1.03457741,  1.40274136],
#        [ 1.21377673,  1.24020308],
#        [ 1.32129632,  1.09740238],
#        [ 1.50049564,  1.51986835],
# ...

# %%
res[:,0].mean()
# Out:
# -7.401486830834377e-18

# %%
res[:,1].mean()
# Out:
# 1.4802973661668754e-17

# %%
res[:,0].std()
# Out:
# 1.0

# %%
res[:,1].std()
# Out:
# 0.9999999999999999

# %% [markdown]
# ### RobustScaler

# %%
scaling_RS=RobustScaler()
res=scaling_RS.fit_transform(df)
# Out:
#   Cell In[9], line 2
#     res=scaling_RS.fit_transfo rm(df)
#                                ^
# SyntaxError: invalid syntax

# %%
res[:,0].mean()
# Out:
# -7.401486830834377e-18

# %% [markdown]
# ### MinMaxScaler

# %%
scaling_MMS=MinMaxScaler()
res=scaling_MMS.fit_transform(df)

# %%
res[:,0].mean()
