# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score
from matplotlib import pyplot

# %%
df=pd.read_csv(r"D:\Roshan raj Mahato\Desktop\Data Analytics\Data_Science_By_Santash_Sir\Datasets\Ice_cream selling data.csv")

# %%
df.columns
# Out:
# Index(['Temperature (°C)', 'Ice Cream Sales (units)'], dtype='object')

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=42)

# %%
# poly=PolynomialFeatures(degree=2)

# poly.fit(X) # .fit(X) Add X^2 (Learn the Pattern feature ,only added X^2 feature column Did Not Add the Values)

# poly.transform(X) # It add the values in x^2 feature 

# poly.fit_transform(X)
