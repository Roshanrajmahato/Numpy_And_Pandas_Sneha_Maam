# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'D:\Roshan raj Mahato\Desktop\Data Analytics\Data_Science_By_Santash_Sir\Datasets\Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
y = df['Salary']

# %%
df['x_mean'] = x-x.mean()

# %%
df['y_mean'] = y-y.mean()

# %%
df['x_mean*y_mean'] = df['x_mean']*df['y_mean']

# %%
df['x_mean**2']= df['x_mean']**2

# %%
slope = df['x_mean*y_mean'].sum( )/df['x_mean**2'].sum( )

# %%
slope
# Out:
# 9449.962321455077

# %% [markdown]
# rate of change of salary is 9449.962321455077 with respect to x = 1

# %%
intersepter = y.mean()-(slope*x.mean())

# %%
intersepter
# Out:
# YearsExperience    25792.200199
# dtype: float64

# %%
#base or initail salary of  person is 25792.20019866869 if the expericens x is 0

# %%
df.head()
# Out:
#    YearsExperience   Salary    x_mean   y_mean  x_mean*y_mean  x_mean**2
# 0              1.1  39343.0 -4.213333 -36660.0  154460.800000  17.752178
# 1              1.3  46205.0 -4.013333 -29798.0  119589.306667  16.106844
# 2              1.5  37731.0 -3.813333 -38272.0  145943.893333  14.541511
# 3              2.0  43525.0 -3.313333 -32478.0  107610.440000  10.978178
# 4              2.2  39891.0 -3.113333 -36112.0  112428.693333   9.692844

# %%
X =df[['YearsExperience']]
y = df['Salary']

# %% [markdown]
# split tarin and test data

# %%
from sklearn.model_selection import train_test_split
'''
syntax:-
xtrain,xtest,ytrain,ytest = 
train_test_split(x,y,random_state=42,train_size=0.8)'''
# Out:
# '\nsyntax:-\nxtrain,xtest,ytrain,ytest = \ntrain_test_split(x,y,random_state=42,train_size=0.8)'

# %%
values = train_test_split(x,y,train_size=0.8,random_state=2)
print(len(values))
# Out:
# 4

# %%
len(values[0])
# Out:
# 24

# %%
values[0]
# Out:
#     YearsExperience
# 23              8.2
# 6               3.0
# 3               2.0
# 20              6.8
# 5               2.9
# 27              9.6
# 12              4.0
# 4               2.2
# 10              3.9
# 16              5.1
# 28             10.3
# 25              9.0
# 17              5.3
# 2               1.5
# 7               3.2
# 26              9.5
# 24              8.7
# 18              5.9
# 11              4.0
# 22              7.9
# 29             10.5
# 13              4.1
# 15              4.9
# 8               3.2

# %%
values[1]
# Out:
#     YearsExperience
# 1               1.3
# 0               1.1
# 14              4.5
# 9               3.7
# 21              7.1
# 19              6.0

# %%
len(values[1])
# Out:
# 6

# %%
values[2]
# Out:
# 23    113812.0
# 6      60150.0
# 3      43525.0
# 20     91738.0
# 5      56642.0
# 27    112635.0
# 12     56957.0
# 4      39891.0
# 10     63218.0
# 16     66029.0
# 28    122391.0
# 25    105582.0
# 17     83088.0
# 2      37731.0
# 7      54445.0
# 26    116969.0
# 24    109431.0
# 18     81363.0
# 11     55794.0
# 22    101302.0
# 29    121872.0
# 13     57081.0
# 15     67938.0
# 8      64445.0
# Name: Salary, dtype: float64

# %%
len(values[2])
# Out:
# 24

# %%
values[3]
# Out:
# 1     46205.0
# 0     39343.0
# 14    61111.0
# 9     57189.0
# 21    98273.0
# 19    93940.0
# Name: Salary, dtype: float64

# %%
len(values[3])
# Out:
# 6

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()             # creating model

# %%
# fit   is train model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.intercept_ # .intercept_ slope :- the base or initail of salary is 25792.200198668717 if experience is 0.
# Out:
# 25792.200198668717

# %%
model.coef_ # .coef_ :- it slope (Rate of change of salary is  with respect to y(experience) )
# Out:
# array([9449.96232146])

# %%
# .predict(X) :- To get the predicted value from model 
#  Internal 
#  y = mX + C
#  y=9449.96232146 X + 25792.200198668717
yprict=model.predict(X)

# %%
df['Predicted_Values']=yprict

# %%
df
# Out:
#     YearsExperience    Salary    x_mean   y_mean  x_mean*y_mean  x_mean**2  \
# 0               1.1   39343.0 -4.213333 -36660.0  154460.800000  17.752178
# 1               1.3   46205.0 -4.013333 -29798.0  119589.306667  16.106844
# 2               1.5   37731.0 -3.813333 -38272.0  145943.893333  14.541511
# 3               2.0   43525.0 -3.313333 -32478.0  107610.440000  10.978178
# 4               2.2   39891.0 -3.113333 -36112.0  112428.693333   9.692844
# 5               2.9   56642.0 -2.413333 -19361.0   46724.546667   5.824178
# 6               3.0   60150.0 -2.313333 -15853.0   36673.273333   5.351511
# 7               3.2   54445.0 -2.113333 -21558.0   45559.240000   4.466178
# 8               3.2   64445.0 -2.113333 -11558.0   24425.906667   4.466178
# 9               3.7   57189.0 -1.613333 -18814.0   30353.253333   2.602844
# 10              3.9   63218.0 -1.413333 -12785.0   18069.466667   1.997511
# ...

# %%
df['Error']=df['Salary']-df['Predicted_Values']

# %%
df
# Out:
#     YearsExperience    Salary    x_mean   y_mean  x_mean*y_mean  x_mean**2  \
# 0               1.1   39343.0 -4.213333 -36660.0  154460.800000  17.752178
# 1               1.3   46205.0 -4.013333 -29798.0  119589.306667  16.106844
# 2               1.5   37731.0 -3.813333 -38272.0  145943.893333  14.541511
# 3               2.0   43525.0 -3.313333 -32478.0  107610.440000  10.978178
# 4               2.2   39891.0 -3.113333 -36112.0  112428.693333   9.692844
# 5               2.9   56642.0 -2.413333 -19361.0   46724.546667   5.824178
# 6               3.0   60150.0 -2.313333 -15853.0   36673.273333   5.351511
# 7               3.2   54445.0 -2.113333 -21558.0   45559.240000   4.466178
# 8               3.2   64445.0 -2.113333 -11558.0   24425.906667   4.466178
# 9               3.7   57189.0 -1.613333 -18814.0   30353.253333   2.602844
# 10              3.9   63218.0 -1.413333 -12785.0   18069.466667   1.997511
# ...

# %%
import matplotlib.pyplot as plot

# %%
# With Actual values
plot.scatter(X,y)
# With Predicted Values
plot.scatter(X,yprict)
