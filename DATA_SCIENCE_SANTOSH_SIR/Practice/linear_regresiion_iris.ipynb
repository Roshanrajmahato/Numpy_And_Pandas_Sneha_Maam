# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plot

# %%
df=pd.read_csv(r"D:\Roshan raj Mahato\Desktop\Data Analytics\Data_Science_By_Santash_Sir\Datasets\Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop("Id",axis=1)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species']=df['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
X=df.iloc[:,:-1]  # Independent features
y=df['Species']   # Dependent features or predict Columns or output

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_pridict=model.predict(X_train)

# %%
model.score(X_test,y_test) 
# X_test Only input Excluding its Output , Taking 0.2 % of Test Data Only
# y_test Output Only , Taking 0.2 % of Test Data Output Only
# Out:
# 0.9467245149351708

# %% [markdown]
# # Scatter Plot for relationship of features

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.scatterplot(data=df,x='SepalLengthCm',y='Species')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %%
plot.scatter(x=df['SepalLengthCm'],y=df['Species'])
plot.xlabel('sepallengrh')
# Out:
# Text(0.5, 0, 'sepallengrh')

# %%
plot.scatter(df['PetalLengthCm'],df['Species'])

# %%
plot.scatter(df['SepalWidthCm'],df['Species'])

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm   Species
# SepalLengthCm       1.000000     -0.109369       0.871754  0.782561
# SepalWidthCm       -0.109369      1.000000      -0.420516 -0.419446
# PetalLengthCm       0.871754     -0.420516       1.000000  0.949043
# Species             0.782561     -0.419446       0.949043  1.000000

# %%
import seaborn as sns

# %%
corr=df.corr()
top_features=corr.index
sns.heatmap(df[top_features].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Now Remove Most effective columns

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df=df.drop("PetalWidthCm", axis=1)
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  Species
# 0            5.1           3.5            1.4        0
# 1            4.9           3.0            1.4        0
# 2            4.7           3.2            1.3        0
# 3            4.6           3.1            1.5        0
# 4            5.0           3.6            1.4        0

# %%
X1=df.iloc[:,:-1]  # Independent features
y1=df['Species']   # Dependent features or predict Columns or output

# %%
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,train_size=0.8,random_state=42)

# %%
model.fit(X1_train,y1_train)
# Out:
# LinearRegression()

# %%
X1_pridict=model.predict(X1_train)

# %%
model.score(X1_test,y1_test) 
# X_test Only input Excluding its Output , Taking 0.2 % of Test Data Only
# y_test Output Only , Taking 0.2 % of Test Data Output Only
# Out:
# 0.9101121714808559

# %%
corr=df.corr()

# %%
corr=df.corr()
top_features=corr.index
sns.heatmap(df[top_features].corr(),annot=True)
# Out:
# <Axes: >
