# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plot

# %%
df=pd.read_csv(r"D:\Roshan raj Mahato\Desktop\Data Analytics\Data_Science_By_Santash_Sir\Datasets\student_performance.csv")
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df['Extracurricular Activities'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Extracurricular Activities']=df['Extracurricular Activities'].map({'No':0,'Yes':1})
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
X=df.drop('Performance Index',axis=1) # Independent features

# %%
y=df["Performance Index"] # Dependent features or predict Columns

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=42)

# %%
X_train # X_train Only input Excluding its Output , Taking 0.8 % of Data Only
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 9254              5               49                           0            7
# 1561              2               48                           1            7
# 1670              2               81                           0            7
# 6087              2               46                           0            6
# 6669              8               47                           0            9
# ...             ...              ...                         ...          ...
# 5734              8               50                           1            6
# 5191              4               68                           0            9
# 5390              9               48                           0            7
# 860               1               47                           0            9
# 7270              2               46                           0            6
#
# ...

# %%
y_train # X_train Output Only , Taking 0.8 % of Data Output Only
# Out:
# 9254    36.0
# 1561    25.0
# 1670    59.0
# 6087    22.0
# 6669    40.0
#         ...
# 5734    48.0
# 5191    51.0
# 5390    44.0
# 860     20.0
# 7270    24.0
# Name: Performance Index, Length: 8000, dtype: float64

# %%
X_test # X_test Only input Excluding its Output , Taking 0.2 % of Test Data Only
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 6252              5               69                           0            8
# 4684              2               46                           1            4
# 1731              7               56                           1            7
# 4742              6               42                           1            8
# 4521              7               53                           0            4
# ...             ...              ...                         ...          ...
# 6412              2               70                           0            7
# 8285              4               79                           0            9
# 7853              2               40                           1            7
# 1095              3               83                           0            7
# 6929              5               60                           0            8
#
# ...

# %%
y_test # y_test Output Only , Taking 0.2 % of Test Data Output Only
# Out:
# 6252    51.0
# 4684    20.0
# 1731    46.0
# 4742    28.0
# 4521    41.0
#         ...
# 6412    45.0
# 8285    66.0
# 7853    16.0
# 1095    65.0
# 6929    47.0
# Name: Performance Index, Length: 2000, dtype: float64

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_pridict=model.predict(X_train)

# %%
model.score(X_test,y_test) 
# X_test Only input Excluding its Output , Taking 0.2 % of Test Data Only
# y_test Output Only , Taking 0.2 % of Test Data Output Only
# Out:
# 0.9889832909573145

# %% [markdown]
# # Scatter Plot for relationship of features

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
plot.scatter(['Hours Studied'],['Performance Index'])

# %%
df.corr()
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...
